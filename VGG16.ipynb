# %%
# %cd /content/drive/My Drive/Colab Notebooks/AIquest/PBL3_ImageClassification
# Out:
# /content/drive/My Drive/Colab Notebooks/AIquest/PBL3_ImageClassification

# %%
# !git config --global user.email "tamana.kenta@hotmail.co.jp"}
# !git config --global user.name "fffukken"

# %%
# !git clone https://github.com/fffukken/PBL3_ImageClassification.git
# Out:
# Cloning into 'PBL3_ImageClassification'...
# ...

# %%
# !git add preprocess.ipynb
# !git commit -m "Added new file."
# Out:
# [master 720b65c] Added new file.
#  1 file changed, 1 insertion(+)
#  create mode 100644 preprocess.ipynb

# %%
# !git remote set-url origin https://fffukken:tata3135@github.com/fffukken/PBL3_ImageClassification.git
# !git push origin master
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 5.90 KiB | 1.47 MiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0)
# To https://github.com/fffukken/PBL3_ImageClassification.git
#  * [new branch]      master -> master

# %%
}import numpy as np
import os

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import VGG16

# %%
train_path = './drive/My Drive/Colab Notebooks/AIquest/PBL3_ImageClassification/train/'
X_train, X_test, y_train, y_test = np.load(train_path + "/train.npy", allow_pickle=True)

# %%
classes = ["regular", "potato", "horn", "bridge"]
num_classes = len(classes)
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

X_test = X_test.astype("float")
X_train = X_train.astype("float")

# %%
IMAGE_SIZE = 224
def model_creation(X_train, y_train, X_test, y_test):
  model = VGG16(
      weights ="imagenet",
      include_top = False,
      input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
  )
  top_model = Sequential()
  top_model.add(Flatten(input_shape=model.output_shape[1:]))
  top_model.add(Dense(256, activation="relu"))
  top_model.add(Dropout(0.5))
  top_model.add(Dense(num_classes, activation="softmax"))
  model = Model(inputs = model.input, outputs=top_model(model.output))

  for layer in model.layers[:15]:
    layer.trainable = False
  
  opt = Adam(lr = 0.001)
  model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics=["accuracy"])
  history = model.fit(X_train, y_train, batch_size=32, epochs=50)

  score = model.evaluate(X_test, y_test, batch_size=32)
  model.save(train_path + "/model.h5")

# %%
model_creation(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 120ms/step - loss: 7.9097 - accuracy: 0.2845
# Epoch 2/50
# 8/8 [==============================] - 1s 120ms/step - loss: 2.2624 - accuracy: 0.3147
# Epoch 3/50
# 8/8 [==============================] - 1s 122ms/step - loss: 1.5584 - accuracy: 0.3233
# Epoch 4/50
# 8/8 [==============================] - 1s 121ms/step - loss: 1.6683 - accuracy: 0.3621
# Epoch 5/50
# 8/8 [==============================] - 1s 122ms/step - loss: 1.9565 - accuracy: 0.3190
# Epoch 6/50
# 8/8 [==============================] - 1s 122ms/step - loss: 1.3532 - accuracy: 0.3534
# Epoch 7/50
# 8/8 [==============================] - 1s 123ms/step - loss: 1.3477 - accuracy: 0.3534
# Epoch 8/50
# 8/8 [==============================] - 1s 123ms/step - loss: 1.3413 - accuracy: 0.3534
# Epoch 9/50
# 8/8 [==============================] - 1s 123ms/step - loss: 1.3347 - accuracy: 0.3534
# Epoch 10/50
# ...

# %%
def image_to_array(image):
  image = image.resize((IMAGE_SIZE, IMAGE_SIZE))
  data = np.asarray(image)
  X = []
  X.append(data)
  X = np.array(X)
  return X

# %%
import glob
import os
from PIL import Image
from tensorflow.keras.models import load_model
test_path = './drive/My Drive/Colab Notebooks/AIquest/PBL3_ImageClassification/test/'
files = glob.glob(test_path + "**")
model = load_model(train_path + "/model.h5")
submit = []

for i, image in enumerate(files):
  image_name = os.path.basename(image)
  image = Image.open(image)

  X = image_to_array(image)
  result = model.predict([X])[0]
  predicted = result.argmax()
  percentage = int(result[predicted]*100)
  # print(predicted, percentage)
  tmp = [image_name, predicted]
  submit.append(tmp)
# Out:
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# 1 35
# ...

# %%
import pandas as pd

df = pd.DataFrame(submit)
df
# Out:
#             0  1
# 0    003.jpeg  1
# 1    002.jpeg  1
# 2    006.jpeg  1
# 3    001.jpeg  1
# 4    005.jpeg  1
# ..        ... ..
# 208  209.jpeg  1
# 209  210.jpeg  1
# 210  207.jpeg  1
# 211  212.jpeg  1
# 212  211.jpeg  1
#
# [213 rows x 2 columns]

# %%
df.columns = ["name", "label"]
df = df.sort_values("name")

# %%
df.to_csv('./drive/My Drive/Colab Notebooks/AIquest/PBL3_ImageClassification/submit/first.tsv', index=False, header=False, sep="\t")
